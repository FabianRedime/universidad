# %%
import pandas as pd
import numpy as np
import datetime
import os
File = pd.read_excel('2019.xlsx')
File
# Out:
#      ID USUARIO DOMO                    NOMBRE Y APELLIDO
# 0               1006         VASQUEZ AGILA JULIO WLADIMIR  \
# 1               1007          ROCHA PROANO HERNAN ROBERTO
# 2               1010      ALEAGA TRUJILLO YESMENI CECIBEL
# 3               1011           CABRERA VEGA SERGIO HERNAN
# 4               1012  CORDOVA REGALADO CARMEN DEL ROSARIO
# ..               ...                                  ...
# 143             1191        OCHOA LUZURIAGA JOSE JONATHAN
# 144             1192           RODRIGUEZ CUEVA JOSE PABLO
# 145             1194         JIMENEZ PARDO ADRIAN ALFONSO
# 146             1195      ACOSTA PADILLA HELENA ALEXANDRA
# 147             1199       SALAZAR LOJA STEFANIE GRACIELA
#
#                               ALIAS             SEGMENTO             AGENCIA
# 0                               NaN                  NaN                 NaN  \
# 1                               NaN                  NaN                 NaN
# ...

# %%
num_rows = len(File)
print("Number of rows:", num_rows)
# Out:
# Number of rows: 148

# %%
import pandas as pd
import numpy as np
import datetime
import os

# Leer el archivo de excel
File = pd.read_excel('doc1_2019.xlsx')
File
# Out:
#                       eid                                              title
# 0      2-s2.0-85124418743  Bases for an Introspective Reconstruction of E...  \
# 1      2-s2.0-85123016303  Are There Opportunities for Sustainable Touris...
# 2      2-s2.0-85122149874  Nest description of Phyllotis andium (Cricetid...
# 3      2-s2.0-85122137710  Incidental consumption of plastic and other an...
# 4      2-s2.0-85123459285  Structure-Function Relationships in the Human ...
# ...                   ...                                                ...
# 16193  2-s2.0-85044348777  Use of denosumab in osteogenesis imperfecta: A...
# 16194  2-s2.0-85037640977  Theoretical study of the furfuryl benzoate and...
# 16195  2-s2.0-85032974666  Treatment challenges in and outside a speciali...
# 16196  2-s2.0-85030482966  Treatment challenges in and outside a network ...
# 16197  2-s2.0-85023601278  Who You Should Not Follow: Extracting Word Emb...
#
# ...

# %%
# Seleccion de las columnas coverDate y descripcion
datos = pd.read_excel('doc1_2019.xlsx', usecols= ["coverDate", "description"])
contador_filas=len(datos)
datos
# Out:
#        coverDate                                        description
# 0     2021-12-31  Latin American ecofeminism (ecofeminisms) need...
# 1     2021-12-30  In recent years, tourism in Ecuador has increa...
# 2     2021-12-30  In this work, we describe the structure of the...
# 3     2021-12-30  This study analyzes and discusses the ingestio...
# 4     2021-12-29  P-Glycoprotein (P-gp) is a transmembrane prote...
# ...          ...                                                ...
# 16193 2019-01-01  Osteogenesis imperfecta (OI) is an inherited d...
# 16194 2019-01-01  In the present work, the pyrolysis reaction me...
# 16195 2019-01-01  Pancreatic Neuroendocrine Neoplasms comprise a...
# 16196 2019-01-01  Patients with soft tissue sarcoma (STS) experi...
# 16197 2019-01-01  In the latest years, a number of citizen movem...
#
# [16198 rows x 2 columns]

# %%
# exporto los datos de las dos columnas en formato csv
datos.to_csv("dataset.csv")
data = pd.read_csv('dataset.csv')
data.head(contador_filas)
# Out:
#        Unnamed: 0   coverDate
# 0               0  2021-12-31  \
# 1               1  2021-12-30
# 2               2  2021-12-30
# 3               3  2021-12-30
# 4               4  2021-12-29
# ...           ...         ...
# 16193       16193  2019-01-01
# 16194       16194  2019-01-01
# 16195       16195  2019-01-01
# 16196       16196  2019-01-01
# 16197       16197  2019-01-01
#
#                                              description
# 0      Latin American ecofeminism (ecofeminisms) need...
# 1      In recent years, tourism in Ecuador has increa...
# 2      In this work, we describe the structure of the...
# 3      This study analyzes and discusses the ingestio...
# 4      P-Glycoprotein (P-gp) is a transmembrane prote...
# ...                                                  ...
# 16193  Osteogenesis imperfecta (OI) is an inherited d...
# 16194  In the present work, the pyrolysis reaction me...
# 16195  Pancreatic Neuroendocrine Neoplasms comprise a...
# ...

# %%
#Obtengo datos de la columna
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16198 entries, 0 to 16197
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   16198 non-null  int64
#  1   coverDate    16198 non-null  object
#  2   description  16198 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 379.8+ KB

# %%
# dejamos solo en el año en la columna coverDate para poder aplicar filtros
data['coverDate']=pd.to_datetime(data["coverDate"])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16198 entries, 0 to 16197
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   16198 non-null  int64
#  1   coverDate    16198 non-null  datetime64[ns]
#  2   description  16198 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 379.8+ KB

# %%
#Dejamos solo el año de la columna coverDate para poder apliacar filtro
data['coverDate']=pd.DatetimeIndex(data['coverDate']).year
data
# Out:
#        Unnamed: 0  coverDate
# 0               0       2021  \
# 1               1       2021
# 2               2       2021
# 3               3       2021
# 4               4       2021
# ...           ...        ...
# 16193       16193       2019
# 16194       16194       2019
# 16195       16195       2019
# 16196       16196       2019
# 16197       16197       2019
#
#                                              description
# 0      Latin American ecofeminism (ecofeminisms) need...
# 1      In recent years, tourism in Ecuador has increa...
# 2      In this work, we describe the structure of the...
# 3      This study analyzes and discusses the ingestio...
# 4      P-Glycoprotein (P-gp) is a transmembrane prote...
# ...                                                  ...
# 16193  Osteogenesis imperfecta (OI) is an inherited d...
# 16194  In the present work, the pyrolysis reaction me...
# 16195  Pancreatic Neuroendocrine Neoplasms comprise a...
# ...

# %%
#Filtramos y exportamos la data del año 2019
data2019 = data[data['coverDate'] == 2019]
data2019.to_csv("dataset2019.csv")
data2019.head(contador_filas)
# Out:
#        Unnamed: 0  coverDate
# 11370       11370       2019  \
# 11371       11371       2019
# 11372       11372       2019
# 11373       11373       2019
# 11374       11374       2019
# ...           ...        ...
# 16193       16193       2019
# 16194       16194       2019
# 16195       16195       2019
# 16196       16196       2019
# 16197       16197       2019
#
#                                              description
# 11370  The objective of this study was to evaluate th...
# 11371  Two new species of Rubiaceae (Condamineeae) ar...
# 11372  Magnolia napoensis, a new species from the Ama...
# 11373  The essential oil of the leaves from Piper ama...
# 11374  The aim of this research was to perform the as...
# ...                                                  ...
# 16193  Osteogenesis imperfecta (OI) is an inherited d...
# 16194  In the present work, the pyrolysis reaction me...
# 16195  Pancreatic Neuroendocrine Neoplasms comprise a...
# ...

# %%
# Leemos todos los elementos del archivo 2019
lecturaCsv=pd.read_csv("dataset2019.csv")
contador_filasCsv=len(lecturaCsv)
data2019 = pd.read_csv("dataset2019.csv").sample(contador_filasCsv)
data2019.head()
# Out:
#       Unnamed: 0.1  Unnamed: 0  coverDate
# 930          12300       12300       2019  \
# 165          11535       11535       2019
# 1287         12657       12657       2019
# 568          11938       11938       2019
# 4018         15388       15388       2019
#
#                                             description
# 930   Animal mortality due to collisions with vehicl...
# 165   An integral part of the antiviral innate immun...
# 1287  This is the first report of Odontopus abdomina...
# 568   This paper reports an investigation of the eff...
# 4018  In this work, we present a harmonized quality ...

# %%
# Cargamos la libreria RE 
import re

data2019['description_processed'] = \
data2019['description'].map(lambda x:re.sub('[,\.!?]', '', x))
data2019['description_processed'] = \
data2019['description_processed'].map(lambda x: x.lower())
data2019['description_processed'].head()
# Out:
# 930     animal mortality due to collisions with vehicl...
# 165     an integral part of the antiviral innate immun...
# 1287    this is the first report of odontopus abdomina...
# 568     this paper reports an investigation of the eff...
# 4018    in this work we present a harmonized quality f...
# Name: description_processed, dtype: object

# %%
# Import the WordCloud library
from wordcloud import WordCloud

long_string = ','.join(list(data2019['description_processed'].values))
wordcloud = WordCloud(background_color="white",max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
import gensim
from gensim.utils import simple_preprocess
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))
            
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc))
            if word not in stop_words] for doc in texts]

data19 = data2019.description_processed.values.tolist()
data_words = list(sent_to_words(data19))
data_words = remove_stopwords(data_words)


print(data_words[:1][0][:30])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fabia\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['animal', 'mortality', 'due', 'collisions', 'vehicles', 'roads', 'major', 'threat', 'biodiversity', 'however', 'still', 'much', 'learn', 'problem', 'tropical', 'andes', 'hot', 'spot', 'describe', 'general', 'patterns', 'bird', 'mortality', 'associated', 'presence', 'road', 'bisects', 'cajas', 'national', 'park']

# %%
import gensim.corpora as corpora
id2word = corpora.Dictionary(data_words)

texts= data_words

corpus = [id2word.doc2bow(text) for text in texts]

print(corpus[:1][0][:30])
# Out:
# [(0, 2), (1, 1), (2, 3), (3, 1), (4, 1), (5, 1), (6, 1), (7, 1), (8, 1), (9, 2), (10, 1), (11, 1), (12, 2), (13, 1), (14, 2), (15, 1), (16, 2), (17, 1), (18, 1), (19, 1), (20, 1), (21, 1), (22, 1), (23, 1), (24, 1), (25, 1), (26, 1), (27, 1), (28, 2), (29, 1)]

# %%
from pprint import pprint
num_topics = 10
lda_model = gensim.models.LdaMulticore(corpus=corpus,id2word=id2word,num_topics=num_topics)
pprint(lda_model.print_topic(3))
doc_lda = lda_model[corpus]
# Out:
# ('0.006*"results" + 0.005*"data" + 0.005*"study" + 0.004*"ecuador" + '
#  '0.004*"based" + 0.004*"model" + 0.004*"used" + 0.003*"time" + '
#  '0.003*"different" + 0.003*"analysis"')

# %%
from gensim.models import CoherenceModel

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_words, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('Coherence Score: ', coherence_lda)
# Out:
# Coherence Score:  0.3356415121475556

# %%
# supporting function
def compute_coherence_values(corpus, dictionary, k, a, b):
    
    lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                           id2word=dictionary,
                                           num_topics=k, 
                                           random_state=100,
                                           chunksize=100,
                                           passes=10,
                                           alpha=a,
                                           eta=b)
    
    coherence_model_lda = CoherenceModel(model=lda_model, texts=data_words, dictionary=id2word, coherence='c_v')
    
    return coherence_model_lda.get_coherence()

# %%
import numpy as np
import tqdm

grid = {}
grid['Validation_Set'] = {}

# Topics range
min_topics = 2
max_topics = 11
step_size = 1
topics_range = range(min_topics, max_topics, step_size)

# Alpha parameter
alpha = list(np.arange(0.01, 1, 0.3))
alpha.append('symmetric')
alpha.append('asymmetric')

# Beta parameter
beta = list(np.arange(0.01, 1, 0.3))
beta.append('symmetric')

# Validation sets
num_of_docs = len(corpus)
corpus_sets = [gensim.utils.ClippedCorpus(corpus, int(num_of_docs*0.75)), 
               corpus]

corpus_title = ['75% Corpus', '100% Corpus']

model_results = {'Validation_Set': [],
                 'Topics': [],
                 'Alpha': [],
                 'Beta': [],
                 'Coherence': []
                }

# Can take a long time to run
if 1 == 1:
    pbar = tqdm.tqdm(total=(len(beta)*len(alpha)*len(topics_range)*len(corpus_title)))
    
    # iterate through validation corpuses
    for i in range(len(corpus_sets)):
        # iterate through number of topics
        for k in topics_range:
            # iterate through alpha values
            for a in alpha:
                # iterare through beta values
                for b in beta:
                    # get the coherence score for the given parameters
                    cv = compute_coherence_values(corpus=corpus_sets[i], dictionary=id2word, 
                                                  k=k, a=a, b=b)
                    # Save the model results
                    model_results['Validation_Set'].append(corpus_title[i])
                    model_results['Topics'].append(k)
                    model_results['Alpha'].append(a)
                    model_results['Beta'].append(b)
                    model_results['Coherence'].append(cv)
                    
                    pbar.update(1)
    pd.DataFrame(model_results).to_csv('lda_tuning_results2019.csv', index=False)
    pbar.close()
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 540/540 [4:24:53<00:00, 29.43s/it]

# %%
import pyLDAvis.gensim_models as gensimvis
import pickle 
import pyLDAvis

# Visualize the topics
pyLDAvis.enable_notebook()

LDAvis_data_filepath = os.path.join('lda_tuning_results2019_'+str(num_topics))

# # this is a bit time consuming - make the if statement True
# # if you want to execute visualization prep yourself
if 1 == 1:
    LDAvis_prepared = gensimvis.prepare(lda_model, corpus, id2word)
    with open(LDAvis_data_filepath, 'wb') as f:
        pickle.dump(LDAvis_prepared, f)

# load the pre-prepared pyLDAvis data from disk
with open(LDAvis_data_filepath, 'rb') as f:
    LDAvis_prepared = pickle.load(f)

pyLDAvis.save_html(LDAvis_prepared, 'lda_tuning_results2019_'+ str(num_topics) +'.html')

LDAvis_prepared
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 8      0.004429 -0.004052       1        1  21.190194
# 7      0.008851  0.008787       2        1  11.944605
# 1      0.021523 -0.014240       3        1  10.957642
# 0      0.013006  0.002722       4        1  10.627614
# 4      0.004049  0.017056       5        1  10.372257
# 3     -0.004881 -0.010727       6        1   8.883257
# 9      0.000637 -0.002327       7        1   7.492145
# 2     -0.030342  0.022879       8        1   6.919836
# 6      0.007101  0.009394       9        1   6.576377
# 5     -0.024373 -0.029492      10        1   5.036073, topic_info=             Term         Freq        Total Category  logprob  loglift
# 281         model  1645.000000  1645.000000  Default  30.0000  30.0000
# 19           data  2030.000000  2030.000000  Default  29.0000  29.0000
# 1636       energy   779.000000   779.000000  Default  28.0000  28.0000
# ...
